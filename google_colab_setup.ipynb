# %% [markdown]
# The following cell clones the SimpleITK notebooks repository into your colab workspace and installs all the required dependencies.

# %%
# !git clone https://github.com/InsightSoftwareConsortium/SimpleITK-Notebooks
# %cd SimpleITK-Notebooks
# !pip install -q -r Python/requirements.txt

# %% [markdown]
# To access the notebooks:
#
# 1. Use the file browser, icon on the left.
# 2. Navigate to `SimpleITK-Notebooks/Python/`
# 3. Double-click any notebook to open it.
